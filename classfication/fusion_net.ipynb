# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import functional as F
import torch.optim as optim
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import wave
import librosa
from python_speech_features import *
import re
from allennlp.commands.elmo import ElmoEmbedder

# %%
prefix = '/Users/apple/Downloads/depression/'

elmo = ElmoEmbedder()

train_split_df = pd.read_csv(prefix+'train_split_Depression_AVEC2017 (1).csv')
test_split_df = pd.read_csv(prefix+'dev_split_Depression_AVEC2017.csv')
train_split_num = train_split_df[['Participant_ID']]['Participant_ID'].tolist()
test_split_num = test_split_df[['Participant_ID']]['Participant_ID'].tolist()
train_split_clabel = train_split_df[['PHQ8_Binary']]['PHQ8_Binary'].tolist()
test_split_clabel = test_split_df[['PHQ8_Binary']]['PHQ8_Binary'].tolist()

topics = []
with open('/Users/apple/Downloads/depression/queries.txt', 'r') as f:
    for line in f.readlines():
        topics.append(line.strip('\n').strip())
        

def identify_topics(sentence):
    if sentence in topics:
        return True
    return False

def extract_features(number, features, target, mode, targets):
    transcript = pd.read_csv(prefix+'{0}_P/{0}_TRANSCRIPT.csv'.format(number), sep='\t').fillna('')
    
    wavefile = wave.open(prefix+'{0}_P/{0}_AUDIO.wav'.format(number, 'r'))
    sr = wavefile.getframerate()
    nframes = wavefile.getnframes()
    wave_data = np.frombuffer(wavefile.readframes(nframes), dtype=np.short)
    
    responses = []
    response = ''
    response_flag = False
    start_time = 0
    stop_time = 0
    signal = []

    global counter_train, counter_test

    for t in transcript.itertuples():
        # participant一句话结束
        if getattr(t,'speaker') == 'Ellie':
            if '(' in getattr(t,'value'):
                content = re.findall(re.compile(r'[(](.*?)[)]', re.S), getattr(t,'value'))[0]
            else:
                content = getattr(t,'value').strip()
            content = getattr(t,'value').strip()
            if identify_topics(content):
                response_flag = True
                if len(response) != 0:
                    responses.append(response.strip())
                response = ''
            elif response_flag and len(content.split()) > 4:
                response_flag = False
                if len(response) != 0:
                    responses.append(response)
                response = ''
        elif getattr(t,'speaker') == 'Participant':
            if 'scrubbed_entry' in getattr(t,'value'):
                continue
            elif response_flag:
                response+=' '+getattr(t,'value').split('\n')[0].strip()
            start_time = int(getattr(t,'start_time')*sr)
            stop_time = int(getattr(t,'stop_time')*sr)
            signal = np.hstack((signal, wave_data[start_time:stop_time].astype(np.float)))
            
#     text features & audio_features
    clip = sr*1*15
    text_features = elmo.embed_sentence(responses).mean(0)
    if target == 1 and mode == 'train':
        times = 3 if counter_train < 51 else 2
        for i in range(times):
#             melspec = base.logfbank(signal[clip*i:clip*(i+1)], samplerate=sr, winlen=0.064, winstep=0.032, nfilt=80, nfft=1024, lowfreq=130, highfreq=6854)
            melspec = librosa.feature.melspectrogram(signal[clip*i:clip*(i+1)], n_mels=80,sr=sr)
            features.append([text_features[i*10:(i+1)*10], melspec])
            targets.append(target)
            counter_train+=1
    else:
#         melspec = base.logfbank(signal[:clip], samplerate=sr, winlen=0.064, winstep=0.032, nfilt=80, nfft=1024, lowfreq=130, highfreq=6854)
        melspec = librosa.feature.melspectrogram(signal[:clip], n_mels=80,sr=sr)
        features.append([text_features[:10], melspec])
        targets.append(target)
        
    print('{}_P feature done'.format(number))
    
    
def extract_features_whole(number, features, target, targets):
    transcript = pd.read_csv(prefix+'{0}_P/{0}_TRANSCRIPT.csv'.format(number), sep='\t').fillna('')
    
    wavefile = wave.open(prefix+'{0}_P/{0}_AUDIO.wav'.format(number, 'r'))
    sr = wavefile.getframerate()
    nframes = wavefile.getnframes()
    wave_data = np.frombuffer(wavefile.readframes(nframes), dtype=np.short)
    
    responses = []
    response = ''
    response_flag = False
    start_time = 0
    stop_time = 0
    signal = []

    global counter_train, counter_test

    for t in transcript.itertuples():
        # participant一句话结束
        if getattr(t,'speaker') == 'Ellie':
            if '(' in getattr(t,'value'):
                content = re.findall(re.compile(r'[(](.*?)[)]', re.S), getattr(t,'value'))[0]
            else:
                content = getattr(t,'value').strip()
            content = getattr(t,'value').strip()
            if identify_topics(content):
                response_flag = True
                if len(response) != 0:
                    responses.append(response.strip())
                response = ''
            elif response_flag and len(content.split()) > 4:
                response_flag = False
                if len(response) != 0:
                    responses.append(response)
                response = ''
        elif getattr(t,'speaker') == 'Participant':
            if 'scrubbed_entry' in getattr(t,'value'):
                continue
            elif response_flag:
                response+=' '+getattr(t,'value').split('\n')[0].strip()
            start_time = int(getattr(t,'start_time')*sr)
            stop_time = int(getattr(t,'stop_time')*sr)
            signal = np.hstack((signal, wave_data[start_time:stop_time].astype(np.float)))
            
#     text features & audio_features
    clip = sr*1*15
    text_features = elmo.embed_sentence(responses).mean(0)
    if target == 1:
        times = 3 if counter_train < 48 else 2
        for i in range(times):
#             melspec = base.logfbank(signal[clip*i:clip*(i+1)], samplerate=sr, winlen=0.064, winstep=0.032, nfilt=80, nfft=1024, lowfreq=130, highfreq=6854)
            melspec = librosa.feature.melspectrogram(signal[clip*i:clip*(i+1)], n_mels=80,sr=sr)
            features.append([text_features[i*10:(i+1)*10], melspec])
            targets.append(target)
            counter_train+=1
    else:
#         melspec = base.logfbank(signal[:clip], samplerate=sr, winlen=0.064, winstep=0.032, nfilt=80, nfft=1024, lowfreq=130, highfreq=6854)
        melspec = librosa.feature.melspectrogram(signal[:clip], n_mels=80,sr=sr)
        features.append([text_features[:10], melspec])
        targets.append(target)
        
    print('{}_P feature done'.format(number))
    
    
counter_train = 0
    
# training set
features_train = []
targets_train = []

# test set
features_test = []
ctargets_test = []

# # training set
# for index in range(len(train_split_num)):
#     extract_features(train_split_num[index], features_train, train_split_clabel[index], 'train', targets_train)
    
# # test set
# for index in range(len(test_split_num)):
#     extract_features(test_split_num[index], features_test, test_split_clabel[index], 'test', ctargets_test)
# print(np.shape(features_train), np.shape(features_test))

features_whole = []
targets_whole = []
whole_split_num = train_split_num + test_split_num
whole_targets = train_split_clabel + test_split_clabel

# for index in range(len(whole_split_num)):
#     extract_features_whole(whole_split_num[index], features_whole, whole_targets[index], targets_whole)
    
# print(np.shape(features_whole), np.shape(targets_whole))

# %%
# print("Saving npz file locally...")

# np.savez(prefix+'data/fuse/train_samples.npz', features_train)
# np.savez(prefix+'data/fuse/test_samples.npz', features_test)
# np.savez(prefix+'data/fuse/train_labels.npz', targets_train)
# np.savez(prefix+'data/fuse/test_labels.npz', ctargets_test)

# np.savez(prefix+'data/fuse/whole_samples.npz', features_whole)
# np.savez(prefix+'data/fuse/whole_labels.npz', targets_whole)

features_train = np.load(prefix+'data/fuse/train_samples.npz', allow_pickle=True)['arr_0']
features_test = np.load(prefix+'data/fuse/test_samples.npz', allow_pickle=True)['arr_0']
targets_train = np.load(prefix+'data/fuse/train_labels.npz', allow_pickle=True)['arr_0']
ctargets_test = np.load(prefix+'data/fuse/test_labels.npz', allow_pickle=True)['arr_0']

X_train = np.array(features_train)
X_test = np.array(features_test)
Y_train = np.array(targets_train)
Y_test = np.array(ctargets_test)

# %%
class BiLSTM(nn.Module):
    def __init__(self, config):
        super(BiLSTM, self).__init__()
        self.num_classes = config['num_classes']
        self.learning_rate = config['learning_rate']
        self.dropout = config['dropout']
        self.hidden_dims = config['hidden_dims']
        self.rnn_layers = config['rnn_layers']
        self.embedding_size = config['embedding_size']

        self.build_model()


    def build_model(self):
        # attention layer
        self.attention_layer = nn.Sequential(
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True)
        )
        # self.attention_weights = self.attention_weights.view(self.hidden_dims, 1)

        # 双层lstm
        self.lstm_net = nn.LSTM(self.embedding_size, self.hidden_dims,
                                num_layers=self.rnn_layers, dropout=self.dropout,
                                bidirectional=True)
        # FC层
        # self.fc_out = nn.Linear(self.hidden_dims, self.num_classes)
        self.fc_out = nn.Sequential(
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True),
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.num_classes)
        )

    def attention_net_with_w(self, lstm_out, lstm_hidden):
        '''
        :param lstm_out:    [batch_size, len_seq, n_hidden * 2]
        :param lstm_hidden: [batch_size, num_layers * num_directions, n_hidden]
        :return: [batch_size, n_hidden]
        '''
        lstm_tmp_out = torch.chunk(lstm_out, 2, -1)
        # h [batch_size, time_step, hidden_dims]
        h = lstm_tmp_out[0] + lstm_tmp_out[1]
        # [batch_size, num_layers * num_directions, n_hidden]
        lstm_hidden = torch.sum(lstm_hidden, dim=1)
        # [batch_size, 1, n_hidden]
        lstm_hidden = lstm_hidden.unsqueeze(1)
        # atten_w [batch_size, 1, hidden_dims]
        atten_w = self.attention_layer(lstm_hidden)
        # m [batch_size, time_step, hidden_dims]
        m = nn.Tanh()(h)
        # atten_context [batch_size, 1, time_step]
        atten_context = torch.bmm(atten_w, m.transpose(1, 2))
        # softmax_w [batch_size, 1, time_step]
        softmax_w = F.softmax(atten_context, dim=-1)
        # context [batch_size, 1, hidden_dims]
        context = torch.bmm(softmax_w, h)
        result = context.squeeze(1)
        return result

    def forward(self, x):
        
        # x : [len_seq, batch_size, embedding_dim]
        x = x.permute(1, 0, 2)
        output, (final_hidden_state, final_cell_state) = self.lstm_net(x)
        # output : [batch_size, len_seq, n_hidden * 2]
        output = output.permute(1, 0, 2)
        # final_hidden_state : [batch_size, num_layers * num_directions, n_hidden]
        final_hidden_state = final_hidden_state.permute(1, 0, 2)
        # final_hidden_state = torch.mean(final_hidden_state, dim=0, keepdim=True)
        # atten_out = self.attention_net(output, final_hidden_state)
        atten_out = self.attention_net_with_w(output, final_hidden_state)
        return self.fc_out(atten_out)

class oned_cnn(nn.Module):
    def __init__(self, n_classes, kernel_height):
        super(oned_cnn, self).__init__()
        self.n_classes = n_classes
        self.kernel_height = kernel_height
        self.conv_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, (kernel_height, 3), 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 1), stride=(2, 1))  
        )
        kernel_height = int(kernel_height/2)
        self.conv_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, (3, 3), 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 1), stride=(2, 1))  
        )
        kernel_height = int(kernel_height/2)-1
        self.conv_layer3 = nn.Sequential(
            nn.Conv2d(64, 64, (3, 1), 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 1), stride=(2, 1))  
        )
        kernel_height = int(kernel_height/2)-1
        self.conv_layer4 = nn.Sequential(
            nn.Conv2d(64, 64, (3, 1), 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=(2, 1), stride=(2, 1))  
        )
        self.dropout = nn.Dropout(0.5)
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, self.n_classes),
            nn.ReLU()
        )
        
    def forward(self, x):
        x = self.conv_layer1(x)
        x = self.conv_layer2(x)
        x = self.conv_layer3(x)
        x = self.conv_layer4(x)
        x = self.dropout(x)
        
        '''pool_mean = F.adaptive_avg_pool2d(x, (1, 1))
        pool_max = F.adaptive_max_pool2d(x, (1, 1))
        pool_l2 = torch.norm(x.cpu(), dim=(2,3), keepdim=True).cuda()
        x = torch.cat((pool_mean.squeeze(-1), pool_max.squeeze(-1), pool_l2.squeeze(-1)), dim=-1)'''
        x = F.adaptive_max_pool2d(x, (4, 2))
        return self.fc(x)
    
class CNN(nn.Module):
    def __init__(self, n_classes):
        super(CNN, self).__init__()
        self.conv2d_1 = nn.Conv2d(1, 32, (1,7), 1)
        self.conv2d_2 = nn.Conv2d(32, 32, (1,7), 1)
        self.dense_1 = nn.Linear(120736, 128)
        self.dense_2 = nn.Linear(128, 128)
        self.dense_3 = nn.Linear(128, n_classes)
        self.dropout = nn.Dropout(0.5)
        
    def forward(self, x):
        x = F.relu(self.conv2d_1(x))
        x = F.max_pool2d(x, (4, 3), (1, 3))
        x = F.relu(self.conv2d_2(x))
        x = F.max_pool2d(x, (1, 3), (1, 3))
#         flatten in keras
        x = x.permute((0, 2, 3, 1))
        x = x.contiguous().view(-1, 120736)
        x = F.relu(self.dense_1(x))
        x = F.relu(self.dense_2(x))
        x = self.dropout(x)
        output = F.softmax(self.dense_3(x))
        return output

# %%
def save(model, filename):
    save_filename = '{}.pt'.format(filename)
    torch.save(model, save_filename)
    print('Saved as %s' % save_filename)
    
def standard_confusion_matrix(y_test, y_test_pred):
    """
    Make confusion matrix with format:
                  -----------
                  | TP | FP |
                  -----------
                  | FN | TN |
                  -----------
    Parameters
    ----------
    y_true : ndarray - 1D
    y_pred : ndarray - 1D

    Returns
    -------
    ndarray - 2D
    """
    [[tn, fp], [fn, tp]] = confusion_matrix(y_test, y_test_pred)
    return np.array([[tp, fp], [fn, tn]])

def model_performance(y_test, y_test_pred_proba):
    """
    Evaluation metrics for network performance.
    """
#     y_test_pred = y_test_pred_proba.data.max(1, keepdim=True)[1]
    y_test_pred = y_test_pred_proba

    # Computing confusion matrix for test dataset
    conf_matrix = standard_confusion_matrix(y_test, y_test_pred)
    print("Confusion Matrix:")
    print(conf_matrix)

    return y_test_pred, conf_matrix

def plot_roc_curve(y_test, y_score):
    """
    Plots ROC curve for final trained model. Code taken from:
    https://vkolachalama.blogspot.com/2016/05/keras-implementation-of-mlp-neural.html
    """
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.legend(loc="lower right")
    plt.savefig(prefix+'images/BiLSTM_roc.png')
    plt.close()

class fusion_net(nn.Module):
    def __init__(self, embed_size, hidden_dims, rnn_layers, dropout, num_classes, kernel_height):
        super(fusion_net, self).__init__()
        self.embed_size = embed_size
        self.hidden_dims = hidden_dims
        self.rnn_layers = rnn_layers
        self.dropout = dropout
        self.num_classes = num_classes
        self.kernel_height = kernel_height
        
#         ============================= BiLSTM =================================
        
        # attention layer
        self.attention_layer = nn.Sequential(
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True)
        )

        # 双层lstm
        self.lstm_net = nn.LSTM(self.embed_size, self.hidden_dims,
                                num_layers=self.rnn_layers, dropout=self.dropout,
                                bidirectional=True)
        # FC层
        self.fc_out = nn.Sequential(
            nn.Dropout(self.dropout),
            nn.Linear(self.hidden_dims, self.hidden_dims),
            nn.ReLU(inplace=True),
            nn.Dropout(self.dropout)
        )
        
#         ============================= BiLSTM =================================

#         ============================= cnn =============================

        self.conv2d_1 = nn.Conv2d(1, 32, (1,7), 1)
        self.conv2d_2 = nn.Conv2d(32, 32, (1,7), 1)
        self.dense_1 = nn.Linear(120736, 128)
        self.dense_2 = nn.Linear(128, 128)
        self.dropout = nn.Dropout(self.dropout)
        
#         ============================= cnn =============================

#         ============================= last fc layer =============================
        self.fc_final = nn.Sequential(
            nn.Linear(128, self.num_classes),
#             nn.ReLU(),
            nn.Softmax(),
#             nn.Sigmoid()
        )
        
    def attention_net_with_w(self, lstm_out, lstm_hidden):
        '''
        :param lstm_out:    [batch_size, len_seq, n_hidden * 2]
        :param lstm_hidden: [batch_size, num_layers * num_directions, n_hidden]
        :return: [batch_size, n_hidden]
        '''
        lstm_tmp_out = torch.chunk(lstm_out, 2, -1)
        # h [batch_size, time_step, hidden_dims]
        h = lstm_tmp_out[0] + lstm_tmp_out[1]
        # [batch_size, num_layers * num_directions, n_hidden]
        lstm_hidden = torch.sum(lstm_hidden, dim=1)
        # [batch_size, 1, n_hidden]
        lstm_hidden = lstm_hidden.unsqueeze(1)
        # atten_w [batch_size, 1, hidden_dims]
        atten_w = self.attention_layer(lstm_hidden)
        # m [batch_size, time_step, hidden_dims]
        m = nn.Tanh()(h)
        # atten_context [batch_size, 1, time_step]
        atten_context = torch.bmm(atten_w, m.transpose(1, 2))
        # softmax_w [batch_size, 1, time_step]
        softmax_w = F.softmax(atten_context, dim=-1)
        # context [batch_size, 1, hidden_dims]
        context = torch.bmm(softmax_w, h)
        result = context.squeeze(1)
        return result
    
    def pretrained_feature(self, x):
        with torch.no_grad():
            x_text = []
            x_audio = []
            for ele in x:
                x_text.append(ele[0])
                x_audio.append(ele[1])
            x_text, x_audio = Variable(torch.tensor(x_text).type(torch.FloatTensor), requires_grad=False),\
                                Variable(torch.tensor(x_audio).type(torch.FloatTensor), requires_grad=False)
    #         ============================= BiLSTM =================================
            # x : [len_seq, batch_size, embedding_dim]
            x_text = x_text.permute(1, 0, 2)
            output, (final_hidden_state, final_cell_state) = self.lstm_net(x_text)
            # output : [batch_size, len_seq, n_hidden * 2]
            output = output.permute(1, 0, 2)
            # final_hidden_state : [batch_size, num_layers * num_directions, n_hidden]
            final_hidden_state = final_hidden_state.permute(1, 0, 2)
            # final_hidden_state = torch.mean(final_hidden_state, dim=0, keepdim=True)
            # atten_out = self.attention_net(output, final_hidden_state)
            atten_out = self.attention_net_with_w(output, final_hidden_state)
            text_feature = self.fc_out(atten_out)

    #         ============================= BiLSTM =================================

    #         ============================= cnn =============================
            x_audio = x_audio.unsqueeze(1)
            x_audio = F.relu(self.conv2d_1(x_audio))
            x_audio = F.max_pool2d(x_audio, (4, 3), (1, 3))
            x_audio = F.relu(self.conv2d_2(x_audio))
            x_audio = F.max_pool2d(x_audio, (1, 3), (1, 3))
    #         flatten in keras
            x_audio = x_audio.permute((0, 2, 3, 1))
            x_audio = x_audio.contiguous().view(-1, 120736)
            x_audio = F.relu(self.dense_1(x_audio))
            x_audio = F.relu(self.dense_2(x_audio))
            audio_feature = self.dropout(x_audio)
#         ============================= cnn =============================
        return (text_feature, audio_feature)
        
    def forward(self, x): 
        output = self.fc_final(x)
        return output
    
class MyLoss(nn.Module):
    def __init__(self):
        super(MyLoss, self).__init__()
        
    def forward(self, text_feature, audio_feature, target, model):
        weight = model.fc_final[0].weight
        bias = model.fc_final[0].bias
        pred_text = F.linear(text_feature, weight[:, :config['hidden_dims']], bias)
        pred_audio = F.linear(audio_feature, weight[:, config['hidden_dims']:], bias)
        l = nn.CrossEntropyLoss()
        target = torch.tensor(target)
#         l = nn.BCEWithLogitsLoss()
#         target = F.one_hot(target, num_classes=2).type(torch.FloatTensor)
#         print('y: {}\npred_audio: {}\npred_text: {}\n'.format(target, pred_audio.data.max(1, keepdim=True)[1], pred_text.data.max(1, keepdim=True)[1]))
        # return l(pred_text, target) + l(pred_audio, target) + \
        #         config['lambda']*torch.norm(weight[:, :config['hidden_dims']]) + \
        #         config['lambda']*torch.norm(weight[:, config['hidden_dims']:])  
        return l(pred_text, target) + l(pred_audio, target)

# %%
config = {
    'num_classes': 2,
    'dropout': 0.5,
    'rnn_layers': 2,
    'embedding_size': 1024,
    'batch_size': 2,
    'epochs': 60,
    'learning_rate': 1e-4,
    'hidden_dims': 128,
    'kernel_height': 35,
    'cuda': False,
    'lambda': 1e-2,
}

model = fusion_net(config['embedding_size'], config['hidden_dims'], \
                   config['rnn_layers'], config['dropout'], config['num_classes'], config['kernel_height'])

optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
criterion = nn.CrossEntropyLoss()
# criterion = MyLoss()

def train(epoch, X_train, Y_train):
    global max_train_acc, train_acc
    model.train()
    batch_idx = 1
    total_loss = 0
    correct = 0
    for i in range(0, X_train.shape[0], config['batch_size']):
        if i + config['batch_size'] > X_train.shape[0]:
            x, y = X_train[i:], Y_train[i:]
        else:
            x, y = X_train[i:(i+config['batch_size'])], Y_train[i:(i+config['batch_size'])]
        if config['cuda']:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True).cuda(), Variable(torch.from_numpy(y)).cuda()
        # 将模型的参数梯度设置为0
        optimizer.zero_grad()
        text_feature, audio_feature = model.pretrained_feature(x)
        # concat_x = torch.cat((text_feature, audio_feature), dim=1)
        # dot_x = text_feature.mul(audio_feature)
        add_x = text_feature.add(audio_feature)
        output = model(add_x)
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(torch.tensor(y).data.view_as(pred)).cpu().sum()
        loss = criterion(output, torch.tensor(y))
        # loss = criterion(text_feature, audio_feature, y, model)
        # 后向传播调整参数
        loss.backward()
        # 根据梯度更新网络参数
        optimizer.step()
        batch_idx += 1
        # loss.item()能够得到张量中的元素值
        total_loss += loss.item()
    cur_loss = total_loss
#     max_train_acc = correct
    train_acc = correct
    print('Train Epoch: {:2d}\t Learning rate: {:.4f}\tLoss: {:.6f}\t Accuracy: {}/{} ({:.0f}%)\n '.format(
                epoch, config['learning_rate'], cur_loss/len(X_train), correct, len(X_train),
        100. * correct / len(X_train)))


def evaluate(model_name, X_test, Y_test, model):
    model.eval()
    batch_idx = 1
    total_loss = 0
    pred = torch.empty(config['batch_size'], 1).type(torch.LongTensor)
    # global max_train_acc, f1s, accs, recs, precs, fold_idx, train_acc
    global max_train_acc, max_acc,max_f1
    for i in range(0, X_test.shape[0], config['batch_size']):
        if i + config['batch_size'] > X_test.shape[0]:
            x, y = X_test[i:], Y_test[i:]
        else:
            x, y = X_test[i:(i+config['batch_size'])], Y_test[i:(i+config['batch_size'])]
        if config['cuda']:
            x, y = Variable(torch.from_numpy(x).type(torch.FloatTensor), requires_grad=True).cuda(), Variable(torch.from_numpy(y)).cuda()
        text_feature, audio_feature = model.pretrained_feature(x)
        with torch.no_grad():
            add_x = text_feature.add(audio_feature)
            output = model(add_x)
        loss = criterion(output, torch.tensor(y))
        # loss = criterion(text_feature, audio_feature, y, model)
        pred = torch.cat((pred, output.data.max(1, keepdim=True)[1]))
        total_loss += loss.item()
    
    y_test_pred, conf_matrix = model_performance(Y_test, pred[2:])
    
    print('\nTest set: Average loss: {:.4f}'.format(total_loss/len(X_test)))
    # custom evaluation metrics
    print('Calculating additional test metrics...')
    accuracy = float(conf_matrix[0][0] + conf_matrix[1][1]) / np.sum(conf_matrix)
    precision = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[0][1])
    recall = float(conf_matrix[0][0]) / (conf_matrix[0][0] + conf_matrix[1][0])
    f1_score = 2 * (precision * recall) / (precision + recall)
    print("Accuracy: {}".format(accuracy))
    print("Precision: {}".format(precision))
    print("Recall: {}".format(recall))
    print("F1-Score: {}\n".format(f1_score))
    print('='*89)
    
    if max_f1 <= f1_score and max_train_acc >= 149:
        max_f1 = f1_score
        max_acc = accuracy
        save(model, '{}_{:.2f}'.format(model_name, max_f1))
        print('*'*64)
        print('model saved: f1: {}\tacc: {}'.format(max_f1, max_acc))
        print('*'*64)
#     if max_train_acc <= train_acc:
#         max_train_acc = train_acc
#         f1s[fold_idx] = f1_score
#         recs[fold_idx] = recall
#         precs[fold_idx] = precision
#         accs[fold_idx] = accuracy
    return total_loss

# %%
lstm_model = torch.load('/Users/apple/Downloads/depression/BiLSTM_elmo_128_0.83_best.pt')
cnn_model = CNN(2)
cnn_model.load_state_dict(torch.load('/Users/apple/Downloads/depression/cnn_melspec_clf.pt'))

# print("Model's state_dict:")
# for param_tensor in cnn_model.state_dict():
#     print(param_tensor, "\t", cnn_model.state_dict()[param_tensor].size())

merge_ordereddict = lstm_model.state_dict().copy()
merge_ordereddict.update(cnn_model.state_dict())

model.load_state_dict(merge_ordereddict, strict=False)
    
if config['cuda']:
    model = model.cuda()
    
for param in model.parameters():
    param.requires_grad = False

model.fc_final[0].weight.requires_grad = True
model.fc_final[0].bias.requires_grad = True

# %%
max_f1 = -1
max_acc = -1
max_train_acc = -1

for ep in range(1, config['epochs']):
    train(ep, X_train, Y_train)
    tloss = evaluate('fuse', X_test, Y_test, model)
# Out:
# Train Epoch:  1	 Learning rate: 0.0001	Loss: 0.387150	 Accuracy: 83/154 (54%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  2	 Learning rate: 0.0001	Loss: 0.367670	 Accuracy: 89/154 (58%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0001	Loss: 0.419618	 Accuracy: 73/154 (47%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0001	Loss: 0.409878	 Accuracy: 76/154 (49%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0001	Loss: 0.390397	 Accuracy: 82/154 (53%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0001	Loss: 0.390397	 Accuracy: 82/154 (53%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0001	Loss: 0.406631	 Accuracy: 77/154 (50%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0001	Loss: 0.429358	 Accuracy: 70/154 (45%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0001	Loss: 0.370917	 Accuracy: 88/154 (57%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# Train Epoch: 10	 Learning rate: 0.0001	Loss: 0.416371	 Accuracy: 74/154 (48%)
#
# Confusion Matrix:
# [[ 1  2]
#  [11 21]]
#
# Test set: Average loss: 0.3468
# Calculating additional test metrics...
# Accuracy: 0.6285714285714286
# Precision: 0.3333333333333333
# Recall: 0.08333333333333333
# F1-Score: 0.13333333333333333
#
# =========================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-be574f1f2667> in <module>
#       4
#       5 for ep in range(1, config['epochs']):
# ----> 6     train(ep, X_train, Y_train)
#       7     tloss = evaluate('fuse', X_test, Y_test, model)
#
# <ipython-input-39-3ec53781a7cd> in train(epoch, X_train, Y_train)
#      35         # 将模型的参数梯度设置为0
#      36         optimizer.zero_grad()
# ---> 37         text_feature, audio_feature = model.pretrained_feature(x)
#      38         # concat_x = torch.cat((text_feature, audio_feature), dim=1)
#      39         dot_x = text_feature.mul(audio_feature)
#
# <ipython-input-32-c48c0abc0c83> in pretrained_feature(self, x)
#     160             x_audio = x_audio.unsqueeze(1)
#     161             x_audio = F.relu(self.conv2d_1(x_audio))
# --> 162             x_audio = F.max_pool2d(x_audio, (4, 3), (1, 3))
#     163             x_audio = F.relu(self.conv2d_2(x_audio))
#     164             x_audio = F.max_pool2d(x_audio, (1, 3), (1, 3))
#
# ~/anaconda3/lib/python3.7/site-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     136             return if_true(*args, **kwargs)
#     137         else:
# --> 138             return if_false(*args, **kwargs)
#     139
#     140     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     486         stride = torch.jit.annotate(List[int], [])
#     487     return torch.max_pool2d(
# --> 488         input, kernel_size, stride, padding, dilation, ceil_mode)
#     489
#     490 max_pool2d = boolean_dispatch(
#
# KeyboardInterrupt:

# %%
fuse_model = torch.load('/Users/apple/Downloads/depression/fuse_0.85.pt')
tloss = evaluate('fuse', X_test, Y_test, fuse_model)
# Out:
# Confusion Matrix:
# [[11  3]
#  [ 1 20]]
#
# Test set: Average loss: 605395734.3144
# Calculating additional test metrics...
# Accuracy: 0.8857142857142857
# Precision: 0.7857142857142857
# Recall: 0.9166666666666666
# F1-Score: 0.8461538461538461
#
# =========================================================================================
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-10-209d5b14e486> in <module>
#       1 fuse_model = torch.load('/Users/apple/Downloads/depression/fuse_0.85.pt')
# ----> 2 tloss = evaluate('fuse', X_test, Y_test, fuse_model)
#
# <ipython-input-9-258c735e9441> in evaluate(model_name, X_test, Y_test, model)
#      92     print('='*89)
#      93
# ---> 94     if max_f1 <= f1_score and max_train_acc >= 149:
#      95         max_f1 = f1_score
#      96         max_acc = accuracy
#
# UnboundLocalError: local variable 'max_f1' referenced before assignment

# %%
from sklearn.model_selection import StratifiedKFold

features_whole = np.load(prefix+'data/fuse/whole_samples.npz', allow_pickle=True)['arr_0']
targets_whole = np.load(prefix+'data/fuse/whole_labels.npz', allow_pickle=True)['arr_0']
fold = 4
fold_idx = 0
kfold = StratifiedKFold(n_splits=fold, shuffle=True)
max_train_acc = -1
train_acc = -1
f1s = np.zeros(fold)
accs = np.zeros(fold)
precs = np.zeros(fold)
recs = np.zeros(fold)

for train_idx, test_idx in kfold.split(features_whole, targets_whole):
    for ep in range(1, config['epochs']):
        train(ep, features_whole[train_idx], targets_whole[train_idx])
        tloss = evaluate('fuse_cv', features_whole[test_idx], targets_whole[test_idx])
    fold_idx += 1
    max_train_acc = -1
    train_acc = -1
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Train Epoch:  1	 Learning rate: 0.0001	Loss: 27396845.244322	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 30268969.9373
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch:  2	 Learning rate: 0.0001	Loss: 49739154.156523	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 31198778.9012
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0001	Loss: 47398616.441149	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 41997094.7366
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0001	Loss: 37285254.120403	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 34753212.5010
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0001	Loss: 51468462.596763	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 35589533.1408
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0001	Loss: 46531853.908017	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 30882069.7807
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0001	Loss: 28021822.106501	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 26775176.3407
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0001	Loss: 258922782.637154	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[19  1]
#  [ 6 24]]
#
# Test set: Average loss: 54033281.2958
# Calculating additional test metrics...
# Accuracy: 0.86
# Precision: 0.95
# Recall: 0.76
# F1-Score: 0.8444444444444444
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0001	Loss: 33130895.704897	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 43273733.4617
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 10	 Learning rate: 0.0001	Loss: 34694281.418433	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 41120506.9013
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 11	 Learning rate: 0.0001	Loss: 32660248.462600	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 38861813.7811
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 12	 Learning rate: 0.0001	Loss: 33150710.001559	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 36532823.0609
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 13	 Learning rate: 0.0001	Loss: 40465496.678721	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 28749016.9796
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 14	 Learning rate: 0.0001	Loss: 33498973.807163	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 30637885.4608
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 15	 Learning rate: 0.0001	Loss: 27243564.951722	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 29160716.5008
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 16	 Learning rate: 0.0001	Loss: 32525078.438217	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 25891788.1809
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 17	 Learning rate: 0.0001	Loss: 17923150.270132	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 24941981.4608
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 18	 Learning rate: 0.0001	Loss: 9879623.323378	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 27143291.2194
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 19	 Learning rate: 0.0001	Loss: 43381081.423123	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 29581611.2142
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 20	 Learning rate: 0.0001	Loss: 26201265.950670	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 25300131.5394
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 21	 Learning rate: 0.0001	Loss: 174311038.848610	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[19  1]
#  [ 6 24]]
#
# Test set: Average loss: 73527443.5344
# Calculating additional test metrics...
# Accuracy: 0.86
# Precision: 0.95
# Recall: 0.76
# F1-Score: 0.8444444444444444
#
# =========================================================================================
# Train Epoch: 22	 Learning rate: 0.0001	Loss: 68142335.403358	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 63546692.3343
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 23	 Learning rate: 0.0001	Loss: 65776668.280911	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 58479626.2543
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 24	 Learning rate: 0.0001	Loss: 45423022.493199	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 52796537.3003
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 25	 Learning rate: 0.0001	Loss: 70366721.531172	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 46336875.8603
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 26	 Learning rate: 0.0001	Loss: 43245651.603105	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 41551333.7804
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 27	 Learning rate: 0.0001	Loss: 38379816.147081	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 39854660.8204
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 28	 Learning rate: 0.0001	Loss: 587460249.647264	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[18  1]
#  [ 7 24]]
#
# Test set: Average loss: 61192744.0144
# Calculating additional test metrics...
# Accuracy: 0.84
# Precision: 0.9473684210526315
# Recall: 0.72
# F1-Score: 0.8181818181818181
#
# =========================================================================================
# Train Epoch: 29	 Learning rate: 0.0001	Loss: 48081820.036907	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 57893515.2144
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 30	 Learning rate: 0.0001	Loss: 69021728.119700	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 51278982.1003
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 31	 Learning rate: 0.0001	Loss: 26109853.585643	 Accuracy: 143/150 (95%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 46997991.0602
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0001	Loss: 48080523.144093	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 42506945.6203
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0001	Loss: 45731753.489379	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 39833944.6605
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0001	Loss: 29164669.898220	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 36979735.7005
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0001	Loss: 26241766.863780	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 34032915.8594
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0001	Loss: 36719970.389533	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 34497153.3005
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0001	Loss: 41882155.443607	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 31623009.3006
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0001	Loss: 24829902.070017	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 30733209.6206
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0001	Loss: 30600811.283354	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 26267134.7393
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0001	Loss: 30496448.266970	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 27899056.0204
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0001	Loss: 15122870.437636	 Accuracy: 141/150 (94%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 25839988.1803
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0001	Loss: 67216817.849362	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 38323810.5803
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0001	Loss: 52936198.231072	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 33589329.6204
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0001	Loss: 44851487.439353	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 30530976.0204
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0001	Loss: 33135779.454090	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 26646336.9805
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0001	Loss: 41915181.158125	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 27425584.0204
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0001	Loss: 37376998.636048	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 27344604.5005
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0001	Loss: 24858258.170997	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 25233447.7005
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0001	Loss: 37747954.146845	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 22486110.7392
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0001	Loss: 20734312.662950	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 20369316.8192
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0001	Loss: 40769846.436183	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 23160440.6592
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0001	Loss: 23024464.780395	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 25511520.6590
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0001	Loss: 20250263.908203	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 24766626.5789
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0001	Loss: 29420106.998997	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 24859007.0600
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0001	Loss: 23921973.363293	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 28757335.3737
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0001	Loss: 17933847.341019	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 26114457.6137
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0001	Loss: 24485294.745654	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 23116697.9337
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0001	Loss: 48119864.718751	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 36233946.5839
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0001	Loss: 27691846.537905	 Accuracy: 142/150 (95%)
#
# Confusion Matrix:
# [[21  2]
#  [ 4 23]]
#
# Test set: Average loss: 28673860.8191
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9130434782608695
# Recall: 0.84
# F1-Score: 0.8749999999999999
#
# =========================================================================================
# Train Epoch:  1	 Learning rate: 0.0001	Loss: 35690030.648309	 Accuracy: 127/150 (85%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3061091.9004
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch:  2	 Learning rate: 0.0001	Loss: 32540322.861947	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1935256.3806
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0001	Loss: 41602855.346038	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[25  0]
#  [ 0 25]]
#
# Test set: Average loss: 0.0610
# Calculating additional test metrics...
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0001	Loss: 51250812.877633	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[25  0]
#  [ 0 25]]
#
# Test set: Average loss: 0.0610
# Calculating additional test metrics...
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0001	Loss: 177576081.206233	 Accuracy: 126/150 (84%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 19541086.7794
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0001	Loss: 77243860.384558	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[25  0]
#  [ 0 25]]
#
# Test set: Average loss: 0.0601
# Calculating additional test metrics...
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0001	Loss: 58144496.087558	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1780037.1795
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0001	Loss: 31723940.822042	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3033734.4598
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0001	Loss: 28027064.562925	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2429322.3002
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 10	 Learning rate: 0.0001	Loss: 53083240.395528	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2055215.4205
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 11	 Learning rate: 0.0001	Loss: 45837927.394009	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2089578.3006
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 12	 Learning rate: 0.0001	Loss: 39940239.496631	 Accuracy: 129/150 (86%)
#
# Confusion Matrix:
# [[23  0]
#  [ 2 25]]
#
# Test set: Average loss: 3585588.5403
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 1.0
# Recall: 0.92
# F1-Score: 0.9583333333333334
#
# =========================================================================================
# Train Epoch: 13	 Learning rate: 0.0001	Loss: 31739890.819207	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[23  0]
#  [ 2 25]]
#
# Test set: Average loss: 2876720.7002
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 1.0
# Recall: 0.92
# F1-Score: 0.9583333333333334
#
# =========================================================================================
# Train Epoch: 14	 Learning rate: 0.0001	Loss: 40086873.270286	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1389431.1008
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 15	 Learning rate: 0.0001	Loss: 161620609.138991	 Accuracy: 126/150 (84%)
#
# Confusion Matrix:
# [[23  1]
#  [ 2 24]]
#
# Test set: Average loss: 2491249.9800
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9583333333333334
# Recall: 0.92
# F1-Score: 0.9387755102040817
#
# =========================================================================================
# Train Epoch: 16	 Learning rate: 0.0001	Loss: 37981385.900067	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 4572723.2605
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 17	 Learning rate: 0.0001	Loss: 68352112.567136	 Accuracy: 127/150 (85%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3425912.3802
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 18	 Learning rate: 0.0001	Loss: 43267478.751752	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3235395.9001
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 19	 Learning rate: 0.0001	Loss: 56834199.813778	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3760654.1401
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 20	 Learning rate: 0.0001	Loss: 48367635.654994	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3675557.1805
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 21	 Learning rate: 0.0001	Loss: 66398625.469119	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 4453198.1405
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 22	 Learning rate: 0.0001	Loss: 61841067.011743	 Accuracy: 125/150 (83%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3995701.8207
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 23	 Learning rate: 0.0001	Loss: 27040967.286436	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 4231491.9008
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 24	 Learning rate: 0.0001	Loss: 46838448.354669	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 5148556.8610
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 25	 Learning rate: 0.0001	Loss: 98572581.791927	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 19663916.8602
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 26	 Learning rate: 0.0001	Loss: 52049167.265409	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 14044010.3002
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 27	 Learning rate: 0.0001	Loss: 74981413.523546	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1575655.7405
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 28	 Learning rate: 0.0001	Loss: 48657764.308709	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2329479.7404
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 29	 Learning rate: 0.0001	Loss: 38868420.622877	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2816753.9803
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 30	 Learning rate: 0.0001	Loss: 58861492.615187	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 4278439.7404
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 31	 Learning rate: 0.0001	Loss: 234076978.455315	 Accuracy: 125/150 (83%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 30945370.9397
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0001	Loss: 72548251.212615	 Accuracy: 129/150 (86%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 15996028.2197
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0001	Loss: 83794078.543918	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 3631335.7394
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0001	Loss: 52252672.993524	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[23  0]
#  [ 2 25]]
#
# Test set: Average loss: 1096568.3798
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 1.0
# Recall: 0.92
# F1-Score: 0.9583333333333334
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0001	Loss: 57244605.313188	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 849694.7801
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0001	Loss: 56387959.206981	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1207041.3401
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0001	Loss: 53636869.741465	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1209303.1001
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0001	Loss: 33742809.847964	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 709740.8602
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0001	Loss: 65502896.877384	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 347329.3403
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0001	Loss: 25982837.415055	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2091322.9405
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0001	Loss: 30122748.280681	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2285253.1804
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0001	Loss: 53570685.778546	 Accuracy: 126/150 (84%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1292930.6207
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0001	Loss: 43445433.467562	 Accuracy: 128/150 (85%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3833016.3806
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0001	Loss: 37691826.251335	 Accuracy: 129/150 (86%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2157976.3803
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0001	Loss: 46556186.896770	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 1671148.8605
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0001	Loss: 32326905.201985	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[25  0]
#  [ 0 25]]
#
# Test set: Average loss: 0.0611
# Calculating additional test metrics...
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-Score: 1.0
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0001	Loss: 142888230.178979	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 7363746.6201
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0001	Loss: 60513717.985942	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 1405388.8601
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0001	Loss: 41519815.393299	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 533434.9411
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0001	Loss: 39973335.611035	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 2821716.5412
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0001	Loss: 30488011.071958	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3984432.7009
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0001	Loss: 133481683.331474	 Accuracy: 126/150 (84%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 23571644.2197
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0001	Loss: 95754836.924808	 Accuracy: 130/150 (87%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 7876780.8599
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0001	Loss: 34873957.305464	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 5203253.8200
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0001	Loss: 84907699.651899	 Accuracy: 129/150 (86%)
#
# Confusion Matrix:
# [[22  0]
#  [ 3 25]]
#
# Test set: Average loss: 14983955.2606
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 1.0
# Recall: 0.88
# F1-Score: 0.9361702127659575
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0001	Loss: 55213908.527219	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 5840784.7006
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0001	Loss: 52246256.358302	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 2387403.5812
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0001	Loss: 69000844.883404	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3663354.9419
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0001	Loss: 59566007.836022	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3138942.7815
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch:  1	 Learning rate: 0.0001	Loss: 21651152.254430	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 71627025.9622
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch:  2	 Learning rate: 0.0001	Loss: 24434215.118978	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 70514589.4875
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# =========================================================================================
# Train Epoch:  3	 Learning rate: 0.0001	Loss: 26558456.358655	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 72848664.3677
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# =========================================================================================
# Train Epoch:  4	 Learning rate: 0.0001	Loss: 31738672.817548	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 70823126.4479
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# =========================================================================================
# Train Epoch:  5	 Learning rate: 0.0001	Loss: 25293326.395983	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 79967123.8840
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch:  6	 Learning rate: 0.0001	Loss: 14932918.234256	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 76369105.3246
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch:  7	 Learning rate: 0.0001	Loss: 25522562.920354	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 72976446.7681
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# =========================================================================================
# Train Epoch:  8	 Learning rate: 0.0001	Loss: 25254176.263078	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 68410963.8881
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# =========================================================================================
# Train Epoch:  9	 Learning rate: 0.0001	Loss: 24901892.654420	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[22  2]
#  [ 3 23]]
#
# Test set: Average loss: 70810220.1683
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9166666666666666
# Recall: 0.88
# F1-Score: 0.8979591836734694
#
# ...
# Train Epoch: 17	 Learning rate: 0.0001	Loss: 34801614.397061	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4897682.2500
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 18	 Learning rate: 0.0001	Loss: 42142488.063034	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4442554.2501
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 19	 Learning rate: 0.0001	Loss: 44272833.050879	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4480631.6902
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 20	 Learning rate: 0.0001	Loss: 39717653.791121	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[24  3]
#  [ 1 22]]
#
# Test set: Average loss: 5169210.2495
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.8888888888888888
# Recall: 0.96
# F1-Score: 0.923076923076923
#
# =========================================================================================
# Train Epoch: 21	 Learning rate: 0.0001	Loss: 47973177.419741	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 4310283.5294
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 22	 Learning rate: 0.0001	Loss: 47491216.455383	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 4205426.5697
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 23	 Learning rate: 0.0001	Loss: 39051441.842360	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 4390427.2093
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 24	 Learning rate: 0.0001	Loss: 63700362.903786	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4467463.3699
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 25	 Learning rate: 0.0001	Loss: 41934989.693785	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4209045.4499
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 26	 Learning rate: 0.0001	Loss: 38059608.706788	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[23  1]
#  [ 2 24]]
#
# Test set: Average loss: 4995731.0496
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9583333333333334
# Recall: 0.92
# F1-Score: 0.9387755102040817
#
# =========================================================================================
# Train Epoch: 27	 Learning rate: 0.0001	Loss: 30067664.764134	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4292240.3298
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 28	 Learning rate: 0.0001	Loss: 56017151.857841	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 14611885.1292
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 29	 Learning rate: 0.0001	Loss: 42908801.202666	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 5428417.7693
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 30	 Learning rate: 0.0001	Loss: 62221313.437223	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[24  3]
#  [ 1 22]]
#
# Test set: Average loss: 9474204.1693
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.8888888888888888
# Recall: 0.96
# F1-Score: 0.923076923076923
#
# =========================================================================================
# Train Epoch: 31	 Learning rate: 0.0001	Loss: 47240211.495506	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[23  1]
#  [ 2 24]]
#
# Test set: Average loss: 4831990.8897
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9583333333333334
# Recall: 0.92
# F1-Score: 0.9387755102040817
#
# =========================================================================================
# Train Epoch: 32	 Learning rate: 0.0001	Loss: 46090178.373901	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 5690197.6094
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 33	 Learning rate: 0.0001	Loss: 41304055.825982	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 4208279.0500
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 34	 Learning rate: 0.0001	Loss: 22530914.587675	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 3377421.1302
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 35	 Learning rate: 0.0001	Loss: 39790396.342993	 Accuracy: 129/150 (86%)
#
# Confusion Matrix:
# [[23  1]
#  [ 2 24]]
#
# Test set: Average loss: 3117534.7300
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9583333333333334
# Recall: 0.92
# F1-Score: 0.9387755102040817
#
# =========================================================================================
# Train Epoch: 36	 Learning rate: 0.0001	Loss: 19601732.938758	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 3652890.2504
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 37	 Learning rate: 0.0001	Loss: 35997126.448090	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 3493166.4103
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 38	 Learning rate: 0.0001	Loss: 48574477.676347	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 6540071.6897
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 39	 Learning rate: 0.0001	Loss: 28485639.180180	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 5958707.8499
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 40	 Learning rate: 0.0001	Loss: 45339181.946738	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 4466230.4100
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 41	 Learning rate: 0.0001	Loss: 29361764.399294	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 3633587.8506
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 42	 Learning rate: 0.0001	Loss: 29082319.838189	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[25  2]
#  [ 0 23]]
#
# Test set: Average loss: 3993600.9704
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.9259259259259259
# Recall: 1.0
# F1-Score: 0.9615384615384615
#
# =========================================================================================
# Train Epoch: 43	 Learning rate: 0.0001	Loss: 23015962.911835	 Accuracy: 137/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 2828137.2906
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 44	 Learning rate: 0.0001	Loss: 61172107.018118	 Accuracy: 132/150 (88%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 6061827.6899
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 45	 Learning rate: 0.0001	Loss: 45632773.466794	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 5245337.6104
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 46	 Learning rate: 0.0001	Loss: 35886128.806322	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 4737685.4502
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 47	 Learning rate: 0.0001	Loss: 38086944.352010	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 4063335.6903
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 48	 Learning rate: 0.0001	Loss: 30253627.762261	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 3535680.4905
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 49	 Learning rate: 0.0001	Loss: 52643962.597481	 Accuracy: 131/150 (87%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 3705154.5704
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 50	 Learning rate: 0.0001	Loss: 116441902.870425	 Accuracy: 134/150 (89%)
#
# Confusion Matrix:
# [[21  1]
#  [ 4 24]]
#
# Test set: Average loss: 7089821.9304
# Calculating additional test metrics...
# Accuracy: 0.9
# Precision: 0.9545454545454546
# Recall: 0.84
# F1-Score: 0.8936170212765958
#
# =========================================================================================
# Train Epoch: 51	 Learning rate: 0.0001	Loss: 58747409.725020	 Accuracy: 138/150 (92%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 7035962.5704
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 52	 Learning rate: 0.0001	Loss: 52173774.474582	 Accuracy: 139/150 (93%)
#
# Confusion Matrix:
# [[24  2]
#  [ 1 23]]
#
# Test set: Average loss: 6029829.7704
# Calculating additional test metrics...
# Accuracy: 0.94
# Precision: 0.9230769230769231
# Recall: 0.96
# F1-Score: 0.9411764705882353
#
# =========================================================================================
# Train Epoch: 53	 Learning rate: 0.0001	Loss: 38336614.464966	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 4690740.0107
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 54	 Learning rate: 0.0001	Loss: 37314916.408621	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[24  1]
#  [ 1 24]]
#
# Test set: Average loss: 3981222.7311
# Calculating additional test metrics...
# Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1-Score: 0.96
#
# =========================================================================================
# Train Epoch: 55	 Learning rate: 0.0001	Loss: 41030251.614338	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 3753340.3306
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 56	 Learning rate: 0.0001	Loss: 34945911.385038	 Accuracy: 135/150 (90%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3190824.9714
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================
# Train Epoch: 57	 Learning rate: 0.0001	Loss: 58339704.395979	 Accuracy: 133/150 (89%)
#
# Confusion Matrix:
# [[20  1]
#  [ 5 24]]
#
# Test set: Average loss: 11203475.2101
# Calculating additional test metrics...
# Accuracy: 0.88
# Precision: 0.9523809523809523
# Recall: 0.8
# F1-Score: 0.8695652173913043
#
# =========================================================================================
# Train Epoch: 58	 Learning rate: 0.0001	Loss: 28448791.074774	 Accuracy: 136/150 (91%)
#
# Confusion Matrix:
# [[22  1]
#  [ 3 24]]
#
# Test set: Average loss: 3953563.2102
# Calculating additional test metrics...
# Accuracy: 0.92
# Precision: 0.9565217391304348
# Recall: 0.88
# F1-Score: 0.9166666666666666
#
# =========================================================================================
# Train Epoch: 59	 Learning rate: 0.0001	Loss: 30164222.118249	 Accuracy: 140/150 (93%)
#
# Confusion Matrix:
# [[25  1]
#  [ 0 24]]
#
# Test set: Average loss: 3143246.4109
# Calculating additional test metrics...
# Accuracy: 0.98
# Precision: 0.9615384615384616
# Recall: 1.0
# F1-Score: 0.9803921568627451
#
# =========================================================================================

# %%
print("Accuracy: {}".format(np.mean(accs)))
print("Precision: {}".format(np.mean(precs)))
print("Recall: {}".format(np.mean(recs)))
print("F1-Score: {}\n".format(np.mean(f1s)))
print('='*89)
# Out:
# Accuracy: 0.945
# Precision: 0.9585360291882032
# Recall: 0.9299999999999999
# F1-Score: 0.9427670004171882
#
# =========================================================================================

# %%
accs
# Out:
# array([0.9 , 0.98, 0.92, 0.98])
